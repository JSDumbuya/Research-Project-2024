# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from sklearn.metrics.pairwise import cosine_similarity

# Load the uploaded CSV files
preprocessed_data = pd.read_csv('v2_preprocessed_data.csv')
adjectives_data = pd.read_csv('adjectives_from_corpus.csv')

# Prepare the data for Word2Vec
sentences = preprocessed_data['text'].apply(simple_preprocess).tolist()

# Train a Word2Vec model
word2vec_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, sg=1)

# Define male and female keywords
male_keywords = ["he", "him", "his", "man", "male", "men", "boy", "guy", "father", "brother", "son", "gentleman"]
female_keywords = ["she", "her", "hers", "woman", "female", "women", "girl", "lady", "mother", "sister", "daughter", "gentlewoman"]

# Define ultra running terms for different categories
ultra_running_terms = {
    "Physical": (
        "endurance", "stamina", "strength", "agility", "recovery",
        "nutrition", "hydration", "fatigue", "injury", "conditioning",
        "adaptation", "muscle", "pace", "terrain", "distance", 
        "strong", "weak", "fitness"
    ),
    "Performance-Related": (
        "speed", "strategy", "training", "goal-setting", "efficiency",
        "technique", "timing", "monitoring", "pace management", 
        "endurance tests", "personal best", "race day", 
        "competition", "support crew", "equipment", 
        "strong", "weak", "athlete", "performance", "power"
    ),
    "Emotional": (
        "resilience", "motivation", "determination", "euphoria", 
        "frustration", "anxiety", "joy", "isolation", "fear", 
        "accomplishment", "grit", "community", "self-discovery", 
        "perseverance", "confidence", "strong", "weak"
    ),
    "Aesthetic": (
        "scenic", "serene", "majestic", "beautiful", "tranquil",
        "inspiring", "rugged", "vibrant", "picturesque", 
        "challenging", "wild", "adventurous", "ethereal", 
        "breath-taking", "harmonious", "beauty", "elegance", 
        "style", "grace", "charm", "design", "visual", 
        "artistic", "pleasing", "attractive"
    )
}

# Function to get the average vector of a list of words
def get_average_vector(words, model):
    valid_words = [word for word in words if word in model.wv]
    if valid_words:
        return np.mean([model.wv[word] for word in valid_words], axis=0)
    else:
        return None

# Get average vectors for male and female keywords
male_vector = get_average_vector(male_keywords, word2vec_model)
female_vector = get_average_vector(female_keywords, word2vec_model)

# Calculate and print cosine similarities for each word in the ultra running terms
for category, words in ultra_running_terms.items():
    print(f"\nCosine Similarities for Category '{category}':")
    
    for word in words:
        if word in word2vec_model.wv:
            word_vector = word2vec_model.wv[word]
            
            # Similarity to male gendered words
            if male_vector is not None:
                male_similarity = cosine_similarity(word_vector.reshape(1, -1), male_vector.reshape(1, -1))[0][0]
                print(f"  Word: '{word}' -> Similarity to Male Keywords: {male_similarity:.4f}")
            
            # Similarity to female gendered words
            if female_vector is not None:
                female_similarity = cosine_similarity(word_vector.reshape(1, -1), female_vector.reshape(1, -1))[0][0]
                print(f"  Word: '{word}' -> Similarity to Female Keywords: {female_similarity:.4f}")
        else:
            print(f"  Word: '{word}' not found in the model vocabulary.")
# Out:
# Cosine Similarities for Category 'Physical':
#   Word: 'endurance' -> Similarity to Male Keywords: 0.6835
#   Word: 'endurance' -> Similarity to Female Keywords: 0.7637
#   Word: 'stamina' not found in the model vocabulary.
#   Word: 'strength' -> Similarity to Male Keywords: 0.7962
#   Word: 'strength' -> Similarity to Female Keywords: 0.8492
#   Word: 'agility' -> Similarity to Male Keywords: 0.8645
#   Word: 'agility' -> Similarity to Female Keywords: 0.8798
#   Word: 'recovery' -> Similarity to Male Keywords: 0.6722
#   Word: 'recovery' -> Similarity to Female Keywords: 0.6915
#   Word: 'nutrition' -> Similarity to Male Keywords: 0.6219
#   Word: 'nutrition' -> Similarity to Female Keywords: 0.7011
#   Word: 'hydration' -> Similarity to Male Keywords: 0.7360
#   Word: 'hydration' -> Similarity to Female Keywords: 0.7722
#   Word: 'fatigue' -> Similarity to Male Keywords: 0.7793
#   Word: 'fatigue' -> Similarity to Female Keywords: 0.8212
#   Word: 'injury' -> Similarity to Male Keywords: 0.7647
#   Word: 'injury' -> Similarity to Female Keywords: 0.7942
#   Word: 'conditioning' -> Similarity to Male Keywords: 0.8789
#   Word: 'conditioning' -> Similarity to Female Keywords: 0.9027
#   Word: 'adaptation' -> Similarity to Male Keywords: 0.8632
#   Word: 'adaptation' -> Similarity to Female Keywords: 0.8879
#   Word: 'muscle' -> Similarity to Male Keywords: 0.5106
#   Word: 'muscle' -> Similarity to Female Keywords: 0.5690
#   Word: 'pace' -> Similarity to Male Keywords: 0.7231
#   Word: 'pace' -> Similarity to Female Keywords: 0.7448
#   Word: 'terrain' -> Similarity to Male Keywords: 0.5529
#   Word: 'terrain' -> Similarity to Female Keywords: 0.6239
#   Word: 'distance' -> Similarity to Male Keywords: 0.7207
#   Word: 'distance' -> Similarity to Female Keywords: 0.7645
#   Word: 'strong' -> Similarity to Male Keywords: 0.8002
#   Word: 'strong' -> Similarity to Female Keywords: 0.7973
#   Word: 'weak' -> Similarity to Male Keywords: 0.8705
#   Word: 'weak' -> Similarity to Female Keywords: 0.8901
#   Word: 'fitness' -> Similarity to Male Keywords: 0.7042
#   Word: 'fitness' -> Similarity to Female Keywords: 0.7076
#
# Cosine Similarities for Category 'Performance-Related':
#   Word: 'speed' -> Similarity to Male Keywords: 0.7835
#   Word: 'speed' -> Similarity to Female Keywords: 0.8513
#   Word: 'strategy' -> Similarity to Male Keywords: 0.8629
#   Word: 'strategy' -> Similarity to Female Keywords: 0.8837
#   Word: 'training' -> Similarity to Male Keywords: 0.6051
#   Word: 'training' -> Similarity to Female Keywords: 0.6405
#   Word: 'goal-setting' not found in the model vocabulary.
#   Word: 'efficiency' -> Similarity to Male Keywords: 0.8403
#   Word: 'efficiency' -> Similarity to Female Keywords: 0.8706
#   Word: 'technique' -> Similarity to Male Keywords: 0.8371
#   Word: 'technique' -> Similarity to Female Keywords: 0.8738
#   Word: 'timing' -> Similarity to Male Keywords: 0.8907
#   Word: 'timing' -> Similarity to Female Keywords: 0.9102
#   Word: 'monitoring' -> Similarity to Male Keywords: 0.8472
#   Word: 'monitoring' -> Similarity to Female Keywords: 0.8756
#   Word: 'pace management' not found in the model vocabulary.
#   Word: 'endurance tests' not found in the model vocabulary.
#   Word: 'personal best' not found in the model vocabulary.
#   Word: 'race day' not found in the model vocabulary.
#   Word: 'competition' -> Similarity to Male Keywords: 0.8796
#   Word: 'competition' -> Similarity to Female Keywords: 0.9000
#   Word: 'support crew' not found in the model vocabulary.
#   Word: 'equipment' -> Similarity to Male Keywords: 0.8677
#   Word: 'equipment' -> Similarity to Female Keywords: 0.8965
#   Word: 'strong' -> Similarity to Male Keywords: 0.8002
#   Word: 'strong' -> Similarity to Female Keywords: 0.7973
#   Word: 'weak' -> Similarity to Male Keywords: 0.8705
#   Word: 'weak' -> Similarity to Female Keywords: 0.8901
#   Word: 'athlete' -> Similarity to Male Keywords: 0.7300
#   Word: 'athlete' -> Similarity to Female Keywords: 0.8060
#   Word: 'performance' -> Similarity to Male Keywords: 0.7451
#   Word: 'performance' -> Similarity to Female Keywords: 0.7870
#   Word: 'power' -> Similarity to Male Keywords: 0.8570
#   Word: 'power' -> Similarity to Female Keywords: 0.8944
#
# Cosine Similarities for Category 'Emotional':
#   Word: 'resilience' -> Similarity to Male Keywords: 0.9022
#   Word: 'resilience' -> Similarity to Female Keywords: 0.9214
#   Word: 'motivation' -> Similarity to Male Keywords: 0.8196
#   Word: 'motivation' -> Similarity to Female Keywords: 0.8513
#   Word: 'determination' -> Similarity to Male Keywords: 0.8949
#   Word: 'determination' -> Similarity to Female Keywords: 0.9061
#   Word: 'euphoria' -> Similarity to Male Keywords: 0.8743
#   Word: 'euphoria' -> Similarity to Female Keywords: 0.8894
#   Word: 'frustration' -> Similarity to Male Keywords: 0.8604
#   Word: 'frustration' -> Similarity to Female Keywords: 0.8736
#   Word: 'anxiety' -> Similarity to Male Keywords: 0.8658
#   Word: 'anxiety' -> Similarity to Female Keywords: 0.8740
#   Word: 'joy' -> Similarity to Male Keywords: 0.8932
#   Word: 'joy' -> Similarity to Female Keywords: 0.9210
#   Word: 'isolation' -> Similarity to Male Keywords: 0.8687
#   Word: 'isolation' -> Similarity to Female Keywords: 0.8868
#   Word: 'fear' -> Similarity to Male Keywords: 0.8877
#   Word: 'fear' -> Similarity to Female Keywords: 0.9135
#   Word: 'accomplishment' -> Similarity to Male Keywords: 0.9011
#   Word: 'accomplishment' -> Similarity to Female Keywords: 0.9186
#   Word: 'grit' -> Similarity to Male Keywords: 0.9019
#   Word: 'grit' -> Similarity to Female Keywords: 0.9123
#   Word: 'community' -> Similarity to Male Keywords: 0.7271
#   Word: 'community' -> Similarity to Female Keywords: 0.7698
#   Word: 'self-discovery' not found in the model vocabulary.
#   Word: 'perseverance' -> Similarity to Male Keywords: 0.9126
#   Word: 'perseverance' -> Similarity to Female Keywords: 0.9301
#   Word: 'confidence' -> Similarity to Male Keywords: 0.8448
#   Word: 'confidence' -> Similarity to Female Keywords: 0.8809
#   Word: 'strong' -> Similarity to Male Keywords: 0.8002
#   Word: 'strong' -> Similarity to Female Keywords: 0.7973
#   Word: 'weak' -> Similarity to Male Keywords: 0.8705
#   Word: 'weak' -> Similarity to Female Keywords: 0.8901
#
# Cosine Similarities for Category 'Aesthetic':
#   Word: 'scenic' -> Similarity to Male Keywords: 0.8891
#   Word: 'scenic' -> Similarity to Female Keywords: 0.9129
#   Word: 'serene' -> Similarity to Male Keywords: 0.8607
#   Word: 'serene' -> Similarity to Female Keywords: 0.8827
#   Word: 'majestic' not found in the model vocabulary.
#   Word: 'beautiful' -> Similarity to Male Keywords: 0.8005
#   Word: 'beautiful' -> Similarity to Female Keywords: 0.8414
#   Word: 'tranquil' not found in the model vocabulary.
#   Word: 'inspiring' -> Similarity to Male Keywords: 0.9072
#   Word: 'inspiring' -> Similarity to Female Keywords: 0.9320
#   Word: 'rugged' -> Similarity to Male Keywords: 0.7645
#   Word: 'rugged' -> Similarity to Female Keywords: 0.8200
#   Word: 'vibrant' -> Similarity to Male Keywords: 0.8728
#   Word: 'vibrant' -> Similarity to Female Keywords: 0.8934
#   Word: 'picturesque' -> Similarity to Male Keywords: 0.8781
#   Word: 'picturesque' -> Similarity to Female Keywords: 0.8888
#   Word: 'challenging' -> Similarity to Male Keywords: 0.8061
#   Word: 'challenging' -> Similarity to Female Keywords: 0.8566
#   Word: 'wild' -> Similarity to Male Keywords: 0.8605
#   Word: 'wild' -> Similarity to Female Keywords: 0.8856
#   Word: 'adventurous' -> Similarity to Male Keywords: 0.8768
#   Word: 'adventurous' -> Similarity to Female Keywords: 0.9019
#   Word: 'ethereal' not found in the model vocabulary.
#   Word: 'breath-taking' not found in the model vocabulary.
#   Word: 'harmonious' not found in the model vocabulary.
#   Word: 'beauty' -> Similarity to Male Keywords: 0.8581
#   Word: 'beauty' -> Similarity to Female Keywords: 0.8967
#   Word: 'elegance' not found in the model vocabulary.
#   Word: 'style' -> Similarity to Male Keywords: 0.8575
#   Word: 'style' -> Similarity to Female Keywords: 0.9006
#   Word: 'grace' -> Similarity to Male Keywords: 0.7933
#   Word: 'grace' -> Similarity to Female Keywords: 0.8011
#   Word: 'charm' -> Similarity to Male Keywords: 0.9183
#   Word: 'charm' -> Similarity to Female Keywords: 0.9261
#   Word: 'design' -> Similarity to Male Keywords: 0.7245
#   Word: 'design' -> Similarity to Female Keywords: 0.7839
#   Word: 'visual' -> Similarity to Male Keywords: 0.8042
#   Word: 'visual' -> Similarity to Female Keywords: 0.8232
#   Word: 'artistic' not found in the model vocabulary.
#   Word: 'pleasing' -> Similarity to Male Keywords: 0.8758
#   Word: 'pleasing' -> Similarity to Female Keywords: 0.8938
#   Word: 'attractive' -> Similarity to Male Keywords: 0.8355
#   Word: 'attractive' -> Similarity to Female Keywords: 0.8527
