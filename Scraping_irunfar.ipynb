# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Base URL for the races category
base_url = 'https://www.irunfar.com/category/races'

# Function to get the soup object for a given URL
def get_soup(url):
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.content, 'html.parser')
    else:
        print(f"Failed to retrieve page {url}")
        return None

# Function to scrape the main race page for article links
def scrape_article_links(url):
    soup = get_soup(url)
    if soup is None:
        return []

    articles = soup.find_all('article')
    article_links = []

    for article in articles:
        link_tag = article.find('a', href=True)
        if link_tag:
            article_links.append(link_tag['href'])

    return article_links

# Function to scrape a single article page for its content
def scrape_article_content(article_url):
    soup = get_soup(article_url)
    if soup is None:
        return None

    # Attempt to scrape the article title more dynamically
    title = None
    # Try multiple title tag structures
    if soup.find('h1'):
        title = soup.find('h1').get_text(strip=True)
    elif soup.find('h2'):
        title = soup.find('h2').get_text(strip=True)
    elif soup.find('title'):
        title = soup.find('title').get_text(strip=True)

    if not title:
        print(f"Title not found for {article_url}")
        return None

    # Scrape the article content (assuming it's in 'entry-content' class)
    content_div = soup.find('div', class_='entry-content')
    if content_div:
        paragraphs = content_div.find_all('p')
        content = '\n'.join([p.get_text(strip=True) for p in paragraphs])
    else:
        print(f"Content not found for {article_url}")
        return None

    # Return the scraped article with title and content
    return {'title': title, 'url': article_url, 'content': content}

# Main scraping logic
def scrape_irunfar_race_articles(base_url, max_pages=60):
    all_articles = []

    for page_num in range(1, max_pages + 1):
        print(f"Scraping page {page_num}")
        
        if page_num == 1:
            page_url = base_url
        else:
            page_url = f'{base_url}/page/{page_num}'
        
        # Get article links from the page
        article_links = scrape_article_links(page_url)

        # Visit each article and get the content if "results" is in the URL
        for article_url in article_links:
            if 'results' in article_url:  # Only scrape articles with "results" in the URL
                print(f"Scraping article: {article_url}")
                article_data = scrape_article_content(article_url)
                if article_data:
                    all_articles.append(article_data)
    
    return all_articles

# Store results into a DataFrame and save as CSV
def save_articles_to_csv(articles, file_name='irunfar_races_articles_results.csv'):
    df = pd.DataFrame(articles)
    df.to_csv(file_name, index=False)
    print(f"Saved {len(articles)} articles to {file_name}")

# Main Execution
if __name__ == "__main__":
    articles = scrape_irunfar_race_articles(base_url, max_pages=60)  # Adjust max_pages as needed
    save_articles_to_csv(articles)
# Out:
# Scraping page 1
# Scraping article: https://www.irunfar.com/2024-mountain-running-world-cup-finals-trail-race-results
# Scraping article: https://www.irunfar.com/2024-mountain-running-world-cup-finals-vk-results
# Scraping article: https://www.irunfar.com/mammoth-trail-fest-26k-results-joyce-muthoni-njeru-and-elhousine-elazzaoui-dominate
# Scraping article: https://www.irunfar.com/2024-run-rabbit-run-100-mile-results
# Scraping article: https://www.irunfar.com/2024-utmb-results
# Scraping article: https://www.irunfar.com/2024-ccc-results-hawks-wins-again-mccann-victorious-in-step-up-in-distance
# Scraping article: https://www.irunfar.com/2024-occ-results-hemming-and-yao-win-utmb-50k-world-series-final
# Scraping page 2
# Scraping article: https://www.irunfar.com/2024-tds-results
# Scraping article: https://www.irunfar.com/2024-sierre-zinal-results
# Scraping article: https://www.irunfar.com/2024-speedgoat-by-utmb-50k-results
# Scraping article: https://www.irunfar.com/2024-hardrock-100-results
# Scraping page 3
# Scraping article: https://www.irunfar.com/2024-western-states-100-results
# Scraping article: https://www.irunfar.com/2024-broken-arrow-skyrace-23k-results
# Scraping article: https://www.irunfar.com/2015-vibram-hong-kong-100k-results
# Scraping page 56
# Scraping article: https://www.irunfar.com/2014-tnf-ec-50-mile-championships-results
# Scraping article: https://www.irunfar.com/2015-western-states-100-lottery-results
# Scraping article: https://www.irunfar.com/2015-hardrock-100-lottery-results
# Scraping page 57
# Scraping article: https://www.irunfar.com/2014-iau-100k-world-championships-results
# Scraping article: https://www.irunfar.com/2014-les-templiers-results
# Scraping article: https://www.irunfar.com/2014-diagonale-des-fous-results
# Scraping page 58
# Scraping article: https://www.irunfar.com/2014-limone-extreme-skyrace-results
# Scraping article: https://www.irunfar.com/2014-the-rut-50k-results
# Scraping page 59
# Scraping article: https://www.irunfar.com/2014-tnf-ultra-trail-du-mont-blanc-utmb-results
# Scraping article: https://www.irunfar.com/2014-matterhorn-ultraks-46k-results
# Scraping page 60
# Scraping article: https://www.irunfar.com/2014-squamish-50-mile-and-50k-results
# Scraping article: https://www.irunfar.com/2014-speedgoat-50k-results
# Saved 195 articles to irunfar_races_articles_results.csv

# %%
from IPython.display import display

# Display the title and content columns in the DataFrame
display(df[['title', 'content']])
# Out:
#                                                 title  \
# 0   2024 Mountain Running World Cup Finals Trail R...
# 1   2024 Mountain Running World Cup Finals VK Resu...
# 2   Mammoth Trail Fest 26k Results: Joyce Muthoni ...
# 3   2024 Run Rabbit Run 100 Mile Results: Mann Set...
# 4   2024 UTMB Results: A Course Record for Schide ...
# 5   2024 CCC Results: Hawks Wins Again, McCann Vic...
# 6   2024 OCC Results: Hemming and Yao Win UTMB 50k...
# 7   2024 TDS Results: Dohin and Marquet Win for Fr...
# 8   2024 Sierre-Zinal Results: Joyline Chepngeno T...
# 9   2024 Speedgoat by UTMB 50k Results: Sinclair S...
# 10  2024 Hardrock 100 Results: Pommeret and Dauwal...
# 11  2024 Western States 100 Results: Walmsley Wins...
# 12  2024 Broken Arrow Skyrace 23k Results: Njeru a...
# 13  2024 Comrades Marathon Results: Gerda Steyn Se...
# 14  2024 Transvulcania Ultramarathon Results: Jon ...
# 15  2024 Cocodona 250 Mile Results: Entrekin and S...
# 16  2024 Canyons by UTMB 100k Results: Farvard Has...
# 17  2024 Madeira Island Ultra-Trail Results: New W...
#
#                                               content
# 0   The 2024Mountain Running World Cupfinished wit...
# 1   After 10 races across seven countries, the 202...
# 2   The eighth race of the 2024 Golden Trail World...
# 3   TheRun Rabbit Run 100 Milehas been a quintesse...
# 4   For the front of the field, the 2024UTMBis alr...
# 5   The 100-kilometerCCCrace left Courmayeur, Ital...
# 6   The 2024OCCrace started at 8:15 a.m. local tim...
# 7   Here we go! The weeklong group ofUTMBraces in ...
# 8   The 2024Sierre-Zinalmountain race was thrillin...
# 9   The 2024Speedgoat by UTMB 50kkicked off at 6:3...
# 10  \nIt was,Ludovic Pommeret(pre-raceandpost-race...
# 11  For hours,Katie Schide(pre-raceandpost-raceint...
# 12  With start-to-finish dominance, Kenyan athlete...
# 13  At 5:30 a.m. on Sunday, June 9, in the raucous...
# 14  The 2024 Transvulcania Ultramarathon getting u...
# 15  With the 2024 Cocodona 250 Mile frontrunners h...
# 16  At the 2024Canyons by UTMB 100k,Rod Farvardhad...
# 17  Leaving the seaside village of Porto Moniz at ...
